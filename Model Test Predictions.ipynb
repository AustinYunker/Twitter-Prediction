# %% [markdown]
# # Setup and Import

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
sns.set
import spacy
import nltk
import Tweet_Normalizer as tn
import gensim
import gensim.downloader
from gensim.models.fasttext import FastText
from nltk.tokenize.toktok import ToktokTokenizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
import pickle
import prepare_embeddings as pe

# %% [markdown]
# # Load the Training and Test Data

# %%
tweets_train = pd.read_csv("data/train.csv")
tweets_test = pd.read_csv("data/test.csv")

# %% [markdown]
# # Clean the Training Data

# %%
# %%time
#USe tweet scrubber function to clean the data
tweets_train = tn.tweet_scrubber(tweets_train, verbose = True)
# Out:
# Running tweet scrubber...
#
# Dropping unnecessary columns
# Successfully dropped columns!
#
# Normalizing the tweets
# Successfully normalized tweets!
#
# Removing invalid and mispelled words
# Successfully removed invalid and mispelled words!
#
# Successfully scrubbed tweets!
#
# Wall time: 2min 15s

# %%
#Check for blank rows after cleaning. We expect 5
tweets_train = tweets_train.replace(r'^(\s)+$', np.nan, regex = True)
#Drop the empty rows
tweets_train.dropna(subset=["Clean Tweets"], inplace = True)
#Reset the index in place
tweets_train.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Clean the Test Data

# %%
tweets_test.shape
# Out:
# (3263, 4)

# %%
pd.set_option('display.max_colwidth', 2)
tweets_test.head()
# Out:
#                                                                                                text  \
# 0  Just happened a terrible car crash
# 1  Heard about #earthquake is different cities, stay safe everyone.
# 2  there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3  Apocalypse lighting. #Spokane #wildfires
# 4  Typhoon Soudelor kills 28 in China and Taiwan
#
#                                                 Clean Tweets
# 0  happen terrible car crash
# 1  hear earthquake different city stay safe
# 2  forest fire spot pond geese flee across street I not save
# 3  apocalypse lighting spokane wildfire
# 4  typhoon  kill china taiwan

# %%
tweets_test = tn.tweet_scrubber(tweets_test, verbose = True, train = False)
# Out:
# Running tweet scrubber...
#
# Dropping unnecessary columns
# Successfully dropped columns!
#
# Normalizing the tweets
# Successfully normalized tweets!
#
# Removing invalid and mispelled words
# Successfully removed invalid and mispelled words!
#
# Successfully scrubbed tweets!

# %%
tweets_test.tail()
# Out:
#                                                                                                                                              text  \
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTENERS XrWn
# 3259  Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# 3260  Green Line derailment in Chicago http://t.co/UtbXLcBIuY
# 3261  MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3
# 3262  #CityofCalgary has activated its Municipal Emergency Plan. #yycstorm
#
#                                                                          Clean Tweets
# 3258  earthquake safety    safety fastener
# 3259  storm ri bad last hurricane  hard hit yard look like bomb around k still  power
# 3260  green line derailment chicago
# 3261  meg issue hazardous weather outlook
# 3262   activate municipal emergency plan

# %%
#Replace empty tweets with NaN
tweets_test = tweets_test.replace(r'^(\s)+$', np.nan, regex = True)
#Count the number missing
tweets_test["Clean Tweets"].isnull().sum()
# Out:
# 2

# %%
#Take a look at the missing tweets
tweets_test.loc[tweets_test["Clean Tweets"].isnull()]
# Out:
#                        text Clean Tweets
# 748  Vamos Newells           NaN
# 759  @edsheeran tf is innit  NaN

# %%
#Set them to a value
tweets_test.loc[tweets_test["Clean Tweets"].isnull(), "Clean Tweets"] = "no"

# %% [markdown]
# # Tokenize the Test Data

# %%
#Tokenize the training and validation set
tokenizer = ToktokTokenizer()
tokenized_train = [tokenizer.tokenize(text) for text in tweets_train["Clean Tweets"]]
tokenized_test = [tokenizer.tokenize(text) for text in tweets_test["Clean Tweets"]]

# %% [markdown]
# # Word2Vec Model

# %% [markdown]
# ### Generate dense embeddings based on training data

# %%
#Number of features to use
w2v_num_features = 300
#Create the Word2Vec model
w2v_model = gensim.models.Word2Vec(tokenized_train, vector_size=w2v_num_features,
                                   window = 250, epochs=100, min_count=0, sample=1e-3,
                                   sg=1, workers=10)
#Creat the training data
X_train = pe.document_vectorizer(corpus=tokenized_train, model=w2v_model, num_features=w2v_num_features)

#Create the test data
X_test = pe.document_vectorizer(corpus=tokenized_test, model=w2v_model, num_features=w2v_num_features)

# %%
#Check test data shape
print(X_test.shape)
# Out:
# (3263, 300)

# %% [markdown]
# ### Load in Word2Vec Model

# %%
word2vec_model = pickle.load(open("best_w2v_model.sav", 'rb'))

# %%
word2vec_predictions = word2vec_model.predict(X_test)

# %% [markdown]
# # FastText Model

# %% [markdown]
# ### Generate dense embeddings based on training data

# %%
# %%time
#Number of Features
ft_num_features = 300


ft_model = FastText(tokenized_train, vector_size = ft_num_features, window = 250, min_count = 0, 
                    sample=1e-3, sg=1, epochs=100, workers=10)


#Create the training set
X_train = pe.document_vectorizer(corpus=tokenized_train, model=ft_model, num_features=ft_num_features)

#Create the test data
X_test = pe.document_vectorizer(corpus=tokenized_test, model=ft_model, num_features=ft_num_features)
# Out:
# Wall time: 1min 37s

# %%
#Check test data shape
print(X_test.shape)
# Out:
# (3263, 300)

# %% [markdown]
# ### Load in FastText Model

# %%
fasttext_model = pickle.load(open("best_ft_model.sav", "rb"))

# %%
fasttext_predictions = fasttext_model.predict(X_test)

# %% [markdown]
# # GloVe Model

# %% [markdown]
# ### Load in pre-generated dense embeddings

# %%
# %%time
glove_vectors = gensim.downloader.load('glove-twitter-50')
gv_num_features = glove_vectors.vector_size
# Out:
# Wall time: 5min 16s

# %%
#Create training data
X_train = pe.document_vectorizer_glove(corpus=tokenized_train, model=glove_vectors, num_features=gv_num_features)


#Create test data
X_test = pe.document_vectorizer_glove(corpus=tokenized_test, model=glove_vectors, num_features=gv_num_features)

# %%
#Check test data shape
print(X_test.shape)
# Out:
# (3263, 50)

# %% [markdown]
# ### Load in GloVe Model

# %%
glove_model = pickle.load(open("best_glove_model.sav", "rb"))

# %%
glove_predictions = glove_model.predict(X_test)

# %% [markdown]
# # Combine the Results

# %%
test_df = pd.DataFrame({"text": tweets_test["text"], "Clean Tweets": tweets_test["Clean Tweets"], "Word2Vec": word2vec_predictions, "FastText": fasttext_predictions,
                        "GloVe": glove_predictions})

# %%
pd.set_option('display.max_colwidth', 2)
test_df.tail(n=15)
# Out:
#                                                                                                                                              text  \
# 3248  Smackdown tyme this should put me in a good mood again since it got wrecked smh
# 3249  @thrillhho jsyk I haven't stopped thinking abt remus slumped against the bathroom door all day I was wrecked ??????????
# 3250  @stighefootball Begovic has been garbage. He got wrecked by a Red Bull reserve team and everyone else this preseason
# 3251  Wrecked today got my hattrick ????
# 3252  #Ebola #EbolaOutbreak Ebola Virus: Birmingham Ala. Firefighters Quarantined After Possible Exposure Officials Say http://t.co/tjpYlU9fOX
# 3253  Malaysian PM confirms debris is from missing flight MH370 http://t.co/pfAvW5QyqE
# 3254  Officials: Alabama home quarantined over possible Ebola case - Washington Times
# 3255  See the 16yr old PKK suicide bomber who detonated bomb in Turkey Army trench released: Harun Ìàekdar ... http://t.co/hKuT5mSdtP @MsOreo_
# 3256  To conference attendees! The blue line from the airport has DERAILED - please look into taking a taxi to the hotel! See you soon!
# 3257  The death toll in a #IS-suicide car bombing on a #YPG position in the Village of Rajman in the eastern province of Hasaka has risen to 9
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTENERS XrWn
# 3259  Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# 3260  Green Line derailment in Chicago http://t.co/UtbXLcBIuY
# 3261  MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3
# 3262  #CityofCalgary has activated its Municipal Emergency Plan. #yycstorm
#
#                                                                                    Clean Tweets  \
# 3248    put I good mood  got wreck
# 3249    I not stop think  remus slump bathroom door day I wreck
# 3250    garbage got wreck red bull reserve team   preseason
# 3251  wreck today get
# 3252  ebola  ebola virus birmingham ala firefighter quarantine possible exposure official say
# 3253  malaysian pm confirm debris miss flight
# 3254  official alabama home quarantine possible ebola case washington time
# 3255  see yr old  suicide bomber detonate bomb turkey army trench release
# 3256  conference attendee blue line airport derail please look take taxi hotel see soon
# 3257  death toll suicide car bombing  position village  eastern province  rise
# 3258  earthquake safety    safety fastener
# 3259  storm ri bad last hurricane  hard hit yard look like bomb around k still  power
# 3260  green line derailment chicago
# 3261  meg issue hazardous weather outlook
# 3262   activate municipal emergency plan
#
#       Word2Vec  FastText  GloVe
# 3248  0         0         0
# 3249  0         0         0
# 3250  0         0         1
# 3251  0         0         0
# 3252  1         1         1
# 3253  1         1         1
# 3254  1         1         1
# 3255  1         1         1
# 3256  1         1         0
# 3257  1         1         1
# 3258  0         1         1
# 3259  1         1         1
# 3260  1         1         1
# 3261  1         1         1
# 3262  1         1         0

# %% [markdown]
# ### Check which predictions Word2Vec and FastText

# %%
mask = (test_df["Word2Vec"] == 1) & (test_df["FastText"] == 1)
test_df.loc[mask]
# Out:
#                                                                                                                                              text  \
# 0     Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, stay safe everyone.
# 2     there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3     Apocalypse lighting. #Spokane #wildfires
# 4     Typhoon Soudelor kills 28 in China and Taiwan
# ...                                             ...
# 3257  The death toll in a #IS-suicide car bombing on a #YPG position in the Village of Rajman in the eastern province of Hasaka has risen to 9
# 3259  Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# 3260  Green Line derailment in Chicago http://t.co/UtbXLcBIuY
# 3261  MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3
# 3262  #CityofCalgary has activated its Municipal Emergency Plan. #yycstorm
#
#                                                                          Clean Tweets  \
# 0     happen terrible car crash
# 1     hear earthquake different city stay safe
# 2     forest fire spot pond geese flee across street I not save
# 3     apocalypse lighting spokane wildfire
# 4     typhoon  kill china taiwan
# ...                          ...
# 3257  death toll suicide car bombing  position village  eastern province  rise
# 3259  storm ri bad last hurricane  hard hit yard look like bomb around k still  power
# 3260  green line derailment chicago
# 3261  meg issue hazardous weather outlook
# 3262   activate municipal emergency plan
#
#       Word2Vec  FastText  GloVe
# 0     1         1         1
# 1     1         1         1
# 2     1         1         1
# 3     1         1         1
# 4     1         1         1
# ...  ..        ..        ..
# 3257  1         1         1
# 3259  1         1         1
# 3260  1         1         1
# 3261  1         1         1
# 3262  1         1         0
#
# [1163 rows x 5 columns]

# %% [markdown]
# ### Check which predictions Word2Vec and GloVe agree

# %%
mask = (test_df["Word2Vec"] == 1) & (test_df["GloVe"] == 1)
test_df.loc[mask]
# Out:
#                                                                                                                                              text  \
# 0     Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, stay safe everyone.
# 2     there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3     Apocalypse lighting. #Spokane #wildfires
# 4     Typhoon Soudelor kills 28 in China and Taiwan
# ...                                             ...
# 3255  See the 16yr old PKK suicide bomber who detonated bomb in Turkey Army trench released: Harun Ìàekdar ... http://t.co/hKuT5mSdtP @MsOreo_
# 3257  The death toll in a #IS-suicide car bombing on a #YPG position in the Village of Rajman in the eastern province of Hasaka has risen to 9
# 3259  Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# 3260  Green Line derailment in Chicago http://t.co/UtbXLcBIuY
# 3261  MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3
#
#                                                                          Clean Tweets  \
# 0     happen terrible car crash
# 1     hear earthquake different city stay safe
# 2     forest fire spot pond geese flee across street I not save
# 3     apocalypse lighting spokane wildfire
# 4     typhoon  kill china taiwan
# ...                          ...
# 3255  see yr old  suicide bomber detonate bomb turkey army trench release
# 3257  death toll suicide car bombing  position village  eastern province  rise
# 3259  storm ri bad last hurricane  hard hit yard look like bomb around k still  power
# 3260  green line derailment chicago
# 3261  meg issue hazardous weather outlook
#
#       Word2Vec  FastText  GloVe
# 0     1         1         1
# 1     1         1         1
# 2     1         1         1
# 3     1         1         1
# 4     1         1         1
# ...  ..        ..        ..
# 3255  1         1         1
# 3257  1         1         1
# 3259  1         1         1
# 3260  1         1         1
# 3261  1         1         1
#
# [957 rows x 5 columns]

# %% [markdown]
# ### Check which predictions FastText and GloVe agree

# %%
mask = (test_df["FastText"] == 1) & (test_df["GloVe"] == 1)
test_df.loc[mask]
# Out:
#                                                                                                                                              text  \
# 0     Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, stay safe everyone.
# 2     there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3     Apocalypse lighting. #Spokane #wildfires
# 4     Typhoon Soudelor kills 28 in China and Taiwan
# ...                                             ...
# 3257  The death toll in a #IS-suicide car bombing on a #YPG position in the Village of Rajman in the eastern province of Hasaka has risen to 9
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTENERS XrWn
# 3259  Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# 3260  Green Line derailment in Chicago http://t.co/UtbXLcBIuY
# 3261  MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3
#
#                                                                          Clean Tweets  \
# 0     happen terrible car crash
# 1     hear earthquake different city stay safe
# 2     forest fire spot pond geese flee across street I not save
# 3     apocalypse lighting spokane wildfire
# 4     typhoon  kill china taiwan
# ...                          ...
# 3257  death toll suicide car bombing  position village  eastern province  rise
# 3258  earthquake safety    safety fastener
# 3259  storm ri bad last hurricane  hard hit yard look like bomb around k still  power
# 3260  green line derailment chicago
# 3261  meg issue hazardous weather outlook
#
#       Word2Vec  FastText  GloVe
# 0     1         1         1
# 1     1         1         1
# 2     1         1         1
# 3     1         1         1
# 4     1         1         1
# ...  ..        ..        ..
# 3257  1         1         1
# 3258  0         1         1
# 3259  1         1         1
# 3260  1         1         1
# 3261  1         1         1
#
# [1078 rows x 5 columns]

# %% [markdown]
# Overall, it appears that the Word2Vec and FastText models agree on the most on which tweets should be predicted as real disasters.

# %% [markdown]
# ### Vote on Test Prediction

# %%
test_df["Vote"] = np.round((test_df["Word2Vec"] + test_df["FastText"] + test_df["GloVe"]) / 3)
test_df["Vote"] = test_df["Vote"].astype(np.int)

# %% [markdown]
# ### Look at which tweets were predicted as a real disaster based on the vote

# %%
cols = ["text", "Clean Tweets", "Vote"]
mask = test_df["Vote"] == 1
test_df.loc[mask, cols].head(n = 20)
# Out:
#                                                                                                                                                text  \
# 0   Just happened a terrible car crash
# 1   Heard about #earthquake is different cities, stay safe everyone.
# 2   there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3   Apocalypse lighting. #Spokane #wildfires
# 4   Typhoon Soudelor kills 28 in China and Taiwan
# 15  Birmingham Wholesale Market is ablaze BBC News - Fire breaks out at Birmingham's Wholesale Market http://t.co/irWqCEZWEU
# 17  #PreviouslyOnDoyinTv: Toke MakinwaÛªs marriage crisis sets Nigerian Twitter ablaze... http://t.co/CMghxBa2XI
# 23  Rape victim dies as she sets herself ablaze: A 16-year-old girl died of burn injuries as she set herself ablazeÛ_ http://t.co/UK8hNrbOob
# 27  'Burning Rahm': Let's hope City Hall builds a giant wooden mayoral effigy 100 feet tall &amp; sets it ablaze. http://t.co/kFo2mksn6Y @John_Kass
# 29  Accident cleared in #PaTurnpike on PATP EB between PA-18 and Cranberry slow back to #traffic http://t.co/SL0Oqn0Vyr
# 32  #3: Car Recorder ZeroEdgeå¨ Dual-lens Car Camera Vehicle Traffic/Driving History/Accident Camcorder  Large Re... http://t.co/kKFaSJv6Cj
# 34  @Traffic_SouthE @roadpol_east Accident on A27 near Lewes is it Kingston Roundabout rather than A283
# 36  For Legal and Medical Referral Service @1800_Injured Call us at: 1-800-465-87332 #accident #slipandfall #dogbite
# 39  On the #M42 northbound between junctions J3 and J3A there are currently delays of 10 mins due to an accident c... http://t.co/LwI3prBa31
# 41  ACCIDENT - HIT AND RUN - COLD at 500 BLOCK OF SE VISTA TER GRESHAM OR [Gresham Police #PG15000044357] 10:35 #pdx911
# 43  Please donate and spread the word! A training accident left the pole-vaulter Kira GrÌ_nberg a paraplegic http://t.co/6MpnyCl8PK
# 48  'When the aftershock happened (Nepal) we were the last int'l team still there; in a way we were 1st responders.' Chief Collins @LACo_FD
# 52  'We are still living in the aftershock of Hiroshima people are still the scars of history.' - Edward Bond http://t.co/engTl5wrGp
# 56  Bo2 had by far the best competitive maps imo hope bo3 is the same #InVahnWeTrust
# 60  When carelessness leads to an aviation accident the victim has the right to seek compensation for damages. http://t.co/eqAG6rz1vO
#
#                                                                                    Clean Tweets  \
# 0   happen terrible car crash
# 1   hear earthquake different city stay safe
# 2   forest fire spot pond geese flee across street I not save
# 3   apocalypse lighting spokane wildfire
# 4   typhoon  kill china taiwan
# 15  birmingham wholesale market ablaze  news fire break birmingham wholesale market
# 17   toke  marriage crisis set nigerian twitter ablaze
# 23  rape victim die set ablaze year old girl die burn injury set
# 27  burn  let hope city hall build giant wooden mayoral effigy foot tall set ablaze
# 29  accident clear   eb pa cranberry slow back traffic
# 32  car recorder  dual lens car camera vehicle traffic drive history accident camcorder large
# 34    accident near  kingston roundabout rather
# 36  legal medical referral service  call accident
# 39  northbound junction j  currently delay min due accident c
# 41  accident hit run cold block se vista  gresham [ gresham police  ]
# 43  please donate spread word training accident leave pole vaulter   paraplegic
# 48  aftershock happen nepal last  team still way  responder chief
# 52  still live aftershock hiroshima people still scar history edward bond
# 56   far good competitive map imo hope
# 60  carelessness lead aviation accident victim right seek compensation damage
#
#     Vote
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# 15  1
# 17  1
# 23  1
# 27  1
# 29  1
# 32  1
# 34  1
# 36  1
# 39  1
# 41  1
# 43  1
# 48  1
# 52  1
# 56  1
# 60  1

# %% [markdown]
# ### Look at which tweets were predicted as a safe based on the vote

# %%
cols = ["text", "Clean Tweets", "Vote"]
mask = test_df["Vote"] == 0
test_df.loc[mask, cols].head(n = 20)
# Out:
#                                                                                                                                            text  \
# 5   We're shaking...It's an earthquake
# 6   They'd probably still show more life than Arsenal did yesterday, eh? EH?
# 7   Hey! How are you?
# 8   What a nice hat?
# 9   Fuck off!
# 10  No I don't like cold!
# 11  NOOOOOOOOO! Don't do that!
# 12  No don't tell me that!
# 13  What if?!
# 14  Awesome!
# 16  @sunkxssedharry will you wear shorts for race ablaze ?
# 18  Check these out: http://t.co/rOI2NSmEJJ http://t.co/3Tj8ZjiN21 http://t.co/YDUiXEfIpE http://t.co/LxTjc87KLS #nsfw
# 19  PSA: IÛªm splitting my personalities.\r\n\r\n?? techies follow @ablaze_co\r\n?? Burners follow @ablaze
# 20  beware world ablaze sierra leone &amp; guap.
# 21  Burning Man Ablaze! by Turban Diva http://t.co/hodWosAmWS via @Etsy
# 22  Not a diss song. People will take 1 thing and run with it. Smh it's an eye opener though. He is about 2 set the game ablaze @CyhiThePrynce
# 24  SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC
# 25  @CTVToronto the bins in front of the field by my house wer set ablaze the other day flames went rite up the hydro pole wonder if it was him
# 26  #nowplaying Alfons - Ablaze 2015 on Puls Radio #pulsradio http://t.co/aA5BJgWfDv
# 28  @PhilippaEilhart @DhuBlath hurt but her eyes ablaze with insulted anger.
#
#                                                                Clean Tweets  \
# 5   shake earthquake
# 6    probably still show life arsenal yesterday
# 7
# 8   nice hat
# 9   fuck
# 10  no I not like cold
# 11   not
# 12  no not tell I
# 13
# 14  awesome
# 16   wear short race ablaze
# 18  check
# 19  psa  splitting personality techie follow  burner follow ablaze
# 20  beware world ablaze sierra leone
# 21  burn man ablaze turban diva
# 22  not diss song people take thing run  eye opener though set game ablaze
# 24  set ablaze
# 25   bin front field house  set ablaze day flame go rite  pole wonder
# 26    ablaze pul radio
# 28    hurt eye ablaze insulted anger
#
#     Vote
# 5   0
# 6   0
# 7   0
# 8   0
# 9   0
# 10  0
# 11  0
# 12  0
# 13  0
# 14  0
# 16  0
# 18  0
# 19  0
# 20  0
# 21  0
# 22  0
# 24  0
# 25  0
# 26  0
# 28  0

# %% [markdown]
# We can see that for the most part, the tweets labeled as safe appear to be correct except for the first.

# %% [markdown]
# # Check the Competition Submission format

# %%
sub = pd.read_csv("data/sample_submission.csv")

# %%
sub.head(n=10)
# Out:
#    id  target
# 0  0   0
# 1  2   0
# 2  3   0
# 3  9   0
# 4  11  0
# 5  12  0
# 6  21  0
# 7  22  0
# 8  27  0
# 9  29  0

# %%
raw_test = pd.read_csv("data/test.csv")

# %%
raw_test.head()
# Out:
#    id keyword location  \
# 0  0   NaN     NaN
# 1  2   NaN     NaN
# 2  3   NaN     NaN
# 3  9   NaN     NaN
# 4  11  NaN     NaN
#
#                                                                                                text
# 0  Just happened a terrible car crash
# 1  Heard about #earthquake is different cities, stay safe everyone.
# 2  there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3  Apocalypse lighting. #Spokane #wildfires
# 4  Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# ### Create submission based on test id and output from the vote

# %%
test_submission = pd.DataFrame({"id": raw_test["id"], "target": test_df["Vote"]})

# %%
test_submission.head(n = 15)
# Out:
#     id  target
# 0   0   1
# 1   2   1
# 2   3   1
# 3   9   1
# 4   11  1
# 5   12  0
# 6   21  0
# 7   22  0
# 8   27  0
# 9   29  0
# 10  30  0
# 11  35  0
# 12  42  0
# 13  43  0
# 14  45  0

# %% [markdown]
# ### Write the test predictions to a csv file to be uploaded to Kaggle

# %%
test_df.to_csv("data/test_submission")
